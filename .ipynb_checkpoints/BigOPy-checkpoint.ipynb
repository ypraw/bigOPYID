# %% [markdown]
# # BigO : Code Complexity as Data Grows

# %% [markdown]
# ### Contoh 1 (Pangkat)

# %%
from math import pow
import timeit

# %%
def pangkat1(x,y):
    hasil=1
    for i in range(0,y):
        hasil= x*hasil
    return hasil

# %%
def pangkat2(x,y):
    hasil=x**y
    return hasil

# %%
def pangkat3(x,y):
    hasil=pow(x,y)
    return hasil

# %%
print(f'with loop \t {timeit.timeit("pangkat1(100,100)",globals=globals(),number=100000)}')
print(f'with ** operator {timeit.timeit("pangkat2(100,100)",globals=globals(),number=100000)}')
print(f'with pow \t {timeit.timeit("pangkat3(100,100)",globals=globals(),number=100000)}')
# Out:
# with loop 	 0.8459740470025281
# with ** operator 0.07406952400197042
# with pow 	 0.031565015000524

# %% [markdown]
# ## Find Minimum Value on the List

# %%
import time
from random import randrange

# %%
# O(N^2)
def findmin1(data):
    lowest = data[0]
    for i in data:
        isSmallest = True
        for j in data:
            if i > j:
                isSmallest = False
            if isSmallest:
                lowest = i
    return lowest

# %%
# 
def findmin2(data):
    lowest = data[0]
    for i in data:
        if i < lowest:  # di eksekusi selama n
            lowest = i  # dieksekusi 1 kali
    return lowest  #   dieksekusi 1 kali

# %%
def findmin3(data):
    return min(data)

# %% [markdown]
# ### Result find Minimum 1

# %%
x1=[]
y1=[]
for listSize1 in range(1000, 10001, 1000):
    example_list = [randrange(10000) for x in range(listSize1)]
    
    start_time = time.time()
    print(f'minimum value: {findmin1(example_list)}')
    end_time = time.time()
    et=end_time-start_time
    print(f'size list: {listSize1}, time execution: {et:5f}')
    x1.append(listSize1)
    y1.append(et)
print()
# Out:
# minimum value: 1006
# size list: 1000, time execution: 0.052408
# minimum value: 5258
# size list: 2000, time execution: 0.189663
# minimum value: 3940
# size list: 3000, time execution: 0.389572
# minimum value: 542
# size list: 4000, time execution: 0.684842
# minimum value: 1533
# size list: 5000, time execution: 1.095000
# minimum value: 4603
# size list: 6000, time execution: 1.558930
# minimum value: 215
# size list: 7000, time execution: 2.097778
# minimum value: 226
# size list: 8000, time execution: 3.230591
# minimum value: 1783
# size list: 9000, time execution: 3.535063
# minimum value: 2925
# size list: 10000, time execution: 4.659548

# %% [markdown]
# ### Result Find Minimum 2

# %%
x2=[]
y2=[]
for listSize2 in range(1000, 10001, 1000):
    example_list = [randrange(10000) for x in range(listSize2)]
    start_time = time.time()
    print(f'minimum value: {findmin2(example_list)}')
    end_time = time.time()
    et2=end_time-start_time
    print(f'size list: {listSize2}, time execution: {et2:.5f}')
    x2.append(listSize2)
    y2.append(et2)
print()
# Out:
# minimum value: 24
# size list: 1000, time execution: 0.00032
# minimum value: 5
# size list: 2000, time execution: 0.00040
# minimum value: 6
# size list: 3000, time execution: 0.00022
# minimum value: 0
# size list: 4000, time execution: 0.00022
# minimum value: 1
# size list: 5000, time execution: 0.00099
# minimum value: 1
# size list: 6000, time execution: 0.00023
# minimum value: 0
# size list: 7000, time execution: 0.00026
# minimum value: 0
# size list: 8000, time execution: 0.00038
# minimum value: 0
# size list: 9000, time execution: 0.00033
# minimum value: 1
# size list: 10000, time execution: 0.00047

# %% [markdown]
# ### Result find Minimum 3

# %%
x3,y3=[],[]
for listSize3 in range(1000, 10001, 1000):
    example_list3 = [randrange(100000) for x in range(listSize3)]
    start_time = time.time()
    print(f'minimum value: {findmin3(example_list3)}')
    end_time = time.time()
    et3=end_time-start_time
    print(f'size list: {listSize3}, time execution: {end_time-start_time:.5f}')
    x2.append(listSize3)
    y2.append(et3)
# Out:
# minimum value: 73
# size list: 1000, time execution: 0.00017
# minimum value: 35
# size list: 2000, time execution: 0.00018
# minimum value: 7
# size list: 3000, time execution: 0.00017
# minimum value: 34
# size list: 4000, time execution: 0.00019
# minimum value: 7
# size list: 5000, time execution: 0.00019
# minimum value: 4
# size list: 6000, time execution: 0.00039
# minimum value: 28
# size list: 7000, time execution: 0.00025
# minimum value: 8
# size list: 8000, time execution: 0.00025
# minimum value: 13
# size list: 9000, time execution: 0.00029
# minimum value: 3
# size list: 10000, time execution: 0.00040
# minimum value: 19
# size list: 11000, time execution: 0.00038
# minimum value: 1
# size list: 12000, time execution: 0.00039
# minimum value: 3
# size list: 13000, time execution: 0.00039
# minimum value: 23
# size list: 14000, time execution: 0.00061
# minimum value: 2
# size list: 15000, time execution: 0.00033
# minimum value: 5
# size list: 16000, time execution: 0.00059
# minimum value: 2
# size list: 17000, time execution: 0.00039
# minimum value: 1
# size list: 18000, time execution: 0.00038
# minimum value: 10
# size list: 19000, time execution: 0.00041
# minimum value: 7
# size list: 20000, time execution: 0.00043
# minimum value: 11
# size list: 21000, time execution: 0.00047
# minimum value: 9
# size list: 22000, time execution: 0.00052
# minimum value: 0
# size list: 23000, time execution: 0.00074
# minimum value: 2
# size list: 24000, time execution: 0.00054
# minimum value: 4
# size list: 25000, time execution: 0.00055
# minimum value: 1
# size list: 26000, time execution: 0.00063
# minimum value: 14
# size list: 27000, time execution: 0.00064
# minimum value: 4
# size list: 28000, time execution: 0.00060
# minimum value: 7
# size list: 29000, time execution: 0.00068
# minimum value: 0
# size list: 30000, time execution: 0.00060
# minimum value: 1
# size list: 31000, time execution: 0.00065
# minimum value: 2
# size list: 32000, time execution: 0.00069
# minimum value: 5
# size list: 33000, time execution: 0.00070
# minimum value: 0
# size list: 34000, time execution: 0.00076
# minimum value: 2
# size list: 35000, time execution: 0.00075
# minimum value: 2
# size list: 36000, time execution: 0.00075
# minimum value: 7
# size list: 37000, time execution: 0.00078
# minimum value: 0
# size list: 38000, time execution: 0.00076
# minimum value: 3
# size list: 39000, time execution: 0.00083
# minimum value: 6
# size list: 40000, time execution: 0.00091
# minimum value: 0
# size list: 41000, time execution: 0.00090
# minimum value: 10
# size list: 42000, time execution: 0.00106
# minimum value: 2
# size list: 43000, time execution: 0.00097
# minimum value: 4
# size list: 44000, time execution: 0.00097
# minimum value: 3
# size list: 45000, time execution: 0.00100
# minimum value: 0
# size list: 46000, time execution: 0.00104
# minimum value: 4
# size list: 47000, time execution: 0.00107
# minimum value: 3
# size list: 48000, time execution: 0.00112
# minimum value: 1
# size list: 49000, time execution: 0.00168
# minimum value: 6
# size list: 50000, time execution: 0.00131
# minimum value: 0
# size list: 51000, time execution: 0.00121
# minimum value: 2
# size list: 52000, time execution: 0.00136
# minimum value: 0
# size list: 53000, time execution: 0.00126
# minimum value: 1
# size list: 54000, time execution: 0.00135
# minimum value: 0
# size list: 55000, time execution: 0.00117
# minimum value: 0
# size list: 56000, time execution: 0.00109
# minimum value: 0
# size list: 57000, time execution: 0.00132
# minimum value: 0
# size list: 58000, time execution: 0.00133
# minimum value: 0
# size list: 59000, time execution: 0.00133
# minimum value: 1
# size list: 60000, time execution: 0.00123
# minimum value: 0
# size list: 61000, time execution: 0.00117
# minimum value: 1
# size list: 62000, time execution: 0.00146
# minimum value: 3
# size list: 63000, time execution: 0.00216
# minimum value: 4
# size list: 64000, time execution: 0.00133
# minimum value: 0
# size list: 65000, time execution: 0.00130
# minimum value: 0
# size list: 66000, time execution: 0.00156
# minimum value: 1
# size list: 67000, time execution: 0.00165
# minimum value: 0
# size list: 68000, time execution: 0.00155
# minimum value: 0
# size list: 69000, time execution: 0.00213
# minimum value: 0
# size list: 70000, time execution: 0.00188
# minimum value: 1
# size list: 71000, time execution: 0.00163
# minimum value: 0
# size list: 72000, time execution: 0.00226
# minimum value: 2
# size list: 73000, time execution: 0.00177
# minimum value: 0
# size list: 74000, time execution: 0.00215
# minimum value: 0
# size list: 75000, time execution: 0.00162
# minimum value: 0
# size list: 76000, time execution: 0.00152
# minimum value: 0
# size list: 77000, time execution: 0.00163
# minimum value: 1
# size list: 78000, time execution: 0.00160
# minimum value: 0
# size list: 79000, time execution: 0.00155
# minimum value: 1
# size list: 80000, time execution: 0.00193
# minimum value: 2
# size list: 81000, time execution: 0.00198
# minimum value: 0
# size list: 82000, time execution: 0.00188
# minimum value: 0
# size list: 83000, time execution: 0.00177
# minimum value: 0
# size list: 84000, time execution: 0.00160
# minimum value: 1
# size list: 85000, time execution: 0.00178
# minimum value: 3
# size list: 86000, time execution: 0.00177
# minimum value: 0
# size list: 87000, time execution: 0.00184
# minimum value: 0
# size list: 88000, time execution: 0.00193
# minimum value: 1
# size list: 89000, time execution: 0.00184
# minimum value: 2
# size list: 90000, time execution: 0.00190
# minimum value: 0
# size list: 91000, time execution: 0.00267
# minimum value: 0
# size list: 92000, time execution: 0.00181
# minimum value: 0
# size list: 93000, time execution: 0.00196
# minimum value: 2
# size list: 94000, time execution: 0.00210
# minimum value: 2
# size list: 95000, time execution: 0.00215
# minimum value: 1
# size list: 96000, time execution: 0.00193
# minimum value: 0
# size list: 97000, time execution: 0.00190
# minimum value: 0
# size list: 98000, time execution: 0.00198
# minimum value: 0
# size list: 99000, time execution: 0.00212
# minimum value: 0
# size list: 100000, time execution: 0.00209

# %% [markdown]
# ### Visualization

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(x1, y1, 'g-', alpha=1, label="findmin Quadratic")
plt.plot(x2, y2, 'r-', alpha=1, label='findmin linear')
plt.plot(x3, y3, 'b--', alpha=1, label='findmin linear pythonic')
# Label the axes and provide a title
plt.grid(True)
plt.legend()
plt.title("Pangkat Complexity")
plt.show()

# %% [markdown]
# # Searching Complexity

# %% [markdown]
# ### Logarithmic Complexity

# %%
def binarySearch(lst, search):
    lower_bound = 0
    upper_bound = len(lst) - 1
    while True:
        if upper_bound < lower_bound:
            print("Not found.")
            return -1

        i = (lower_bound + upper_bound) // 2

        if lst[i] < search:
            lower_bound = i + 1
        elif lst[i] > search:
            upper_bound = i - 1
        else:
            return [search, i]
    return -1

# %% [markdown]
# ### Liniear Complexity

# %%
def linearSearch(sortedList, target):
    for i in range(len(sortedList)):
        if (sortedList[i] == target):
            return [i, sortedList[i]]
    return -1

# %%
""" Testing Runtime """
size1, size2, time1, time2 = [], [], [], []

for listSize in range(1000, 100001, 1000):
    exampleList = [x for x in range(listSize)]
    start_time = time.time()
    print(
        f"binary search O(log N) : {binarySearch(exampleList,exampleList[len(exampleList)-1])}"
    )
    end_time = time.time()
    et = end_time - start_time
    print(f'size list: {listSize}, time execution: {et:.5f}')
    size1.append(listSize)
    time1.append(et)

print(" ")

for listSize2 in range(1000, 100001, 1000):
    exampleList2 = [x for x in range(listSize2)]
    start_time2 = time.time()
    print(
        f"Linier Search O(N) : {linearSearch(exampleList2,exampleList2[len(exampleList2)-1])}"
    )
    end_time2 = time.time()
    et2 = end_time2 - start_time2
    print(f'size list: {listSize2}, time execution: {et2:.5f}')
    size2.append(listSize2)
    time2.append(et2)
# Out:
# binary search O(log N) : [999, 999]
# size list: 1000, time execution: 0.00013
# binary search O(log N) : [1999, 1999]
# size list: 2000, time execution: 0.00003
# binary search O(log N) : [2999, 2999]
# size list: 3000, time execution: 0.00004
# binary search O(log N) : [3999, 3999]
# size list: 4000, time execution: 0.00005
# binary search O(log N) : [4999, 4999]
# size list: 5000, time execution: 0.00004
# binary search O(log N) : [5999, 5999]
# size list: 6000, time execution: 0.00023
# binary search O(log N) : [6999, 6999]
# size list: 7000, time execution: 0.00004
# binary search O(log N) : [7999, 7999]
# size list: 8000, time execution: 0.00002
# binary search O(log N) : [8999, 8999]
# size list: 9000, time execution: 0.00009
# binary search O(log N) : [9999, 9999]
# size list: 10000, time execution: 0.00004
# binary search O(log N) : [10999, 10999]
# size list: 11000, time execution: 0.00005
# binary search O(log N) : [11999, 11999]
# size list: 12000, time execution: 0.00037
# binary search O(log N) : [12999, 12999]
# size list: 13000, time execution: 0.00008
# binary search O(log N) : [13999, 13999]
# size list: 14000, time execution: 0.00024
# binary search O(log N) : [14999, 14999]
# size list: 15000, time execution: 0.00005
# binary search O(log N) : [15999, 15999]
# size list: 16000, time execution: 0.00008
# binary search O(log N) : [16999, 16999]
# size list: 17000, time execution: 0.00006
# binary search O(log N) : [17999, 17999]
# size list: 18000, time execution: 0.00026
# binary search O(log N) : [18999, 18999]
# size list: 19000, time execution: 0.00008
# binary search O(log N) : [19999, 19999]
# size list: 20000, time execution: 0.00008
# binary search O(log N) : [20999, 20999]
# size list: 21000, time execution: 0.00005
# binary search O(log N) : [21999, 21999]
# size list: 22000, time execution: 0.00029
# binary search O(log N) : [22999, 22999]
# size list: 23000, time execution: 0.00010
# binary search O(log N) : [23999, 23999]
# size list: 24000, time execution: 0.00006
# binary search O(log N) : [24999, 24999]
# size list: 25000, time execution: 0.00019
# binary search O(log N) : [25999, 25999]
# size list: 26000, time execution: 0.00005
# binary search O(log N) : [26999, 26999]
# size list: 27000, time execution: 0.00019
# binary search O(log N) : [27999, 27999]
# size list: 28000, time execution: 0.00012
# binary search O(log N) : [28999, 28999]
# size list: 29000, time execution: 0.00006
# binary search O(log N) : [29999, 29999]
# size list: 30000, time execution: 0.00004
# binary search O(log N) : [30999, 30999]
# size list: 31000, time execution: 0.00004
# binary search O(log N) : [31999, 31999]
# size list: 32000, time execution: 0.00003
# binary search O(log N) : [32999, 32999]
# size list: 33000, time execution: 0.00005
# binary search O(log N) : [33999, 33999]
# size list: 34000, time execution: 0.00008
# binary search O(log N) : [34999, 34999]
# size list: 35000, time execution: 0.00024
# binary search O(log N) : [35999, 35999]
# size list: 36000, time execution: 0.00025
# binary search O(log N) : [36999, 36999]
# size list: 37000, time execution: 0.00014
# binary search O(log N) : [37999, 37999]
# size list: 38000, time execution: 0.00010
# binary search O(log N) : [38999, 38999]
# size list: 39000, time execution: 0.00017
# binary search O(log N) : [39999, 39999]
# size list: 40000, time execution: 0.00004
# binary search O(log N) : [40999, 40999]
# size list: 41000, time execution: 0.00007
# binary search O(log N) : [41999, 41999]
# size list: 42000, time execution: 0.00016
# binary search O(log N) : [42999, 42999]
# size list: 43000, time execution: 0.00007
# binary search O(log N) : [43999, 43999]
# size list: 44000, time execution: 0.00004
# binary search O(log N) : [44999, 44999]
# size list: 45000, time execution: 0.00004
# binary search O(log N) : [45999, 45999]
# size list: 46000, time execution: 0.00005
# binary search O(log N) : [46999, 46999]
# size list: 47000, time execution: 0.00008
# binary search O(log N) : [47999, 47999]
# size list: 48000, time execution: 0.00017
# binary search O(log N) : [48999, 48999]
# size list: 49000, time execution: 0.00004
# binary search O(log N) : [49999, 49999]
# size list: 50000, time execution: 0.00006
# binary search O(log N) : [50999, 50999]
# size list: 51000, time execution: 0.00009
# binary search O(log N) : [51999, 51999]
# size list: 52000, time execution: 0.00016
# binary search O(log N) : [52999, 52999]
# size list: 53000, time execution: 0.00003
# binary search O(log N) : [53999, 53999]
# size list: 54000, time execution: 0.00004
# binary search O(log N) : [54999, 54999]
# size list: 55000, time execution: 0.00003
# binary search O(log N) : [55999, 55999]
# size list: 56000, time execution: 0.00003
# binary search O(log N) : [56999, 56999]
# size list: 57000, time execution: 0.00004
# binary search O(log N) : [57999, 57999]
# size list: 58000, time execution: 0.00005
# binary search O(log N) : [58999, 58999]
# size list: 59000, time execution: 0.00004
# binary search O(log N) : [59999, 59999]
# size list: 60000, time execution: 0.00004
# binary search O(log N) : [60999, 60999]
# size list: 61000, time execution: 0.00008
# binary search O(log N) : [61999, 61999]
# size list: 62000, time execution: 0.00005
# binary search O(log N) : [62999, 62999]
# size list: 63000, time execution: 0.00004
# binary search O(log N) : [63999, 63999]
# size list: 64000, time execution: 0.00007
# binary search O(log N) : [64999, 64999]
# size list: 65000, time execution: 0.00005
# binary search O(log N) : [65999, 65999]
# size list: 66000, time execution: 0.00009
# binary search O(log N) : [66999, 66999]
# size list: 67000, time execution: 0.00012
# binary search O(log N) : [67999, 67999]
# size list: 68000, time execution: 0.00009
# binary search O(log N) : [68999, 68999]
# size list: 69000, time execution: 0.00005
# binary search O(log N) : [69999, 69999]
# size list: 70000, time execution: 0.00005
# binary search O(log N) : [70999, 70999]
# size list: 71000, time execution: 0.00007
# binary search O(log N) : [71999, 71999]
# size list: 72000, time execution: 0.00005
# binary search O(log N) : [72999, 72999]
# size list: 73000, time execution: 0.00004
# binary search O(log N) : [73999, 73999]
# size list: 74000, time execution: 0.00005
# binary search O(log N) : [74999, 74999]
# size list: 75000, time execution: 0.00007
# binary search O(log N) : [75999, 75999]
# size list: 76000, time execution: 0.00007
# binary search O(log N) : [76999, 76999]
# size list: 77000, time execution: 0.00009
# binary search O(log N) : [77999, 77999]
# size list: 78000, time execution: 0.00005
# binary search O(log N) : [78999, 78999]
# size list: 79000, time execution: 0.00007
# binary search O(log N) : [79999, 79999]
# size list: 80000, time execution: 0.00005
# binary search O(log N) : [80999, 80999]
# size list: 81000, time execution: 0.00010
# binary search O(log N) : [81999, 81999]
# size list: 82000, time execution: 0.00019
# binary search O(log N) : [82999, 82999]
# size list: 83000, time execution: 0.00020
# binary search O(log N) : [83999, 83999]
# size list: 84000, time execution: 0.00012
# binary search O(log N) : [84999, 84999]
# size list: 85000, time execution: 0.00005
# binary search O(log N) : [85999, 85999]
# size list: 86000, time execution: 0.00010
# binary search O(log N) : [86999, 86999]
# size list: 87000, time execution: 0.00011
# binary search O(log N) : [87999, 87999]
# size list: 88000, time execution: 0.00010
# binary search O(log N) : [88999, 88999]
# size list: 89000, time execution: 0.00008
# binary search O(log N) : [89999, 89999]
# size list: 90000, time execution: 0.00023
# binary search O(log N) : [90999, 90999]
# size list: 91000, time execution: 0.00023
# binary search O(log N) : [91999, 91999]
# size list: 92000, time execution: 0.00022
# binary search O(log N) : [92999, 92999]
# size list: 93000, time execution: 0.00023
# binary search O(log N) : [93999, 93999]
# size list: 94000, time execution: 0.00015
# binary search O(log N) : [94999, 94999]
# size list: 95000, time execution: 0.00010
# binary search O(log N) : [95999, 95999]
# size list: 96000, time execution: 0.00009
# binary search O(log N) : [96999, 96999]
# size list: 97000, time execution: 0.00007
# binary search O(log N) : [97999, 97999]
# size list: 98000, time execution: 0.00017
# binary search O(log N) : [98999, 98999]
# size list: 99000, time execution: 0.00038
# binary search O(log N) : [99999, 99999]
# size list: 100000, time execution: 0.00023
#
# Linier Search O(N) : [999, 999]
# size list: 1000, time execution: 0.00010
# Linier Search O(N) : [1999, 1999]
# size list: 2000, time execution: 0.00015
# Linier Search O(N) : [2999, 2999]
# size list: 3000, time execution: 0.00020
# Linier Search O(N) : [3999, 3999]
# size list: 4000, time execution: 0.00054
# Linier Search O(N) : [4999, 4999]
# size list: 5000, time execution: 0.00033
# Linier Search O(N) : [5999, 5999]
# size list: 6000, time execution: 0.00048
# Linier Search O(N) : [6999, 6999]
# size list: 7000, time execution: 0.00066
# Linier Search O(N) : [7999, 7999]
# size list: 8000, time execution: 0.00060
# Linier Search O(N) : [8999, 8999]
# size list: 9000, time execution: 0.00085
# Linier Search O(N) : [9999, 9999]
# size list: 10000, time execution: 0.00089
# Linier Search O(N) : [10999, 10999]
# size list: 11000, time execution: 0.00071
# Linier Search O(N) : [11999, 11999]
# size list: 12000, time execution: 0.00080
# Linier Search O(N) : [12999, 12999]
# size list: 13000, time execution: 0.00133
# Linier Search O(N) : [13999, 13999]
# size list: 14000, time execution: 0.00097
# Linier Search O(N) : [14999, 14999]
# size list: 15000, time execution: 0.00134
# Linier Search O(N) : [15999, 15999]
# size list: 16000, time execution: 0.00200
# Linier Search O(N) : [16999, 16999]
# size list: 17000, time execution: 0.00208
# Linier Search O(N) : [17999, 17999]
# size list: 18000, time execution: 0.00127
# Linier Search O(N) : [18999, 18999]
# size list: 19000, time execution: 0.00120
# Linier Search O(N) : [19999, 19999]
# size list: 20000, time execution: 0.00174
# Linier Search O(N) : [20999, 20999]
# size list: 21000, time execution: 0.00156
# Linier Search O(N) : [21999, 21999]
# size list: 22000, time execution: 0.00147
# Linier Search O(N) : [22999, 22999]
# size list: 23000, time execution: 0.00144
# Linier Search O(N) : [23999, 23999]
# size list: 24000, time execution: 0.00153
# Linier Search O(N) : [24999, 24999]
# size list: 25000, time execution: 0.00159
# Linier Search O(N) : [25999, 25999]
# size list: 26000, time execution: 0.00166
# Linier Search O(N) : [26999, 26999]
# size list: 27000, time execution: 0.00173
# Linier Search O(N) : [27999, 27999]
# size list: 28000, time execution: 0.00174
# Linier Search O(N) : [28999, 28999]
# size list: 29000, time execution: 0.00182
# Linier Search O(N) : [29999, 29999]
# size list: 30000, time execution: 0.00196
# Linier Search O(N) : [30999, 30999]
# size list: 31000, time execution: 0.00198
# Linier Search O(N) : [31999, 31999]
# size list: 32000, time execution: 0.00263
# Linier Search O(N) : [32999, 32999]
# size list: 33000, time execution: 0.00324
# Linier Search O(N) : [33999, 33999]
# size list: 34000, time execution: 0.00451
# Linier Search O(N) : [34999, 34999]
# size list: 35000, time execution: 0.00457
# Linier Search O(N) : [35999, 35999]
# size list: 36000, time execution: 0.00507
# Linier Search O(N) : [36999, 36999]
# size list: 37000, time execution: 0.00342
# Linier Search O(N) : [37999, 37999]
# size list: 38000, time execution: 0.00347
# Linier Search O(N) : [38999, 38999]
# size list: 39000, time execution: 0.00302
# Linier Search O(N) : [39999, 39999]
# size list: 40000, time execution: 0.00270
# Linier Search O(N) : [40999, 40999]
# size list: 41000, time execution: 0.00258
# Linier Search O(N) : [41999, 41999]
# size list: 42000, time execution: 0.00295
# Linier Search O(N) : [42999, 42999]
# size list: 43000, time execution: 0.00301
# Linier Search O(N) : [43999, 43999]
# size list: 44000, time execution: 0.00278
# Linier Search O(N) : [44999, 44999]
# size list: 45000, time execution: 0.00285
# Linier Search O(N) : [45999, 45999]
# size list: 46000, time execution: 0.00290
# Linier Search O(N) : [46999, 46999]
# size list: 47000, time execution: 0.00298
# Linier Search O(N) : [47999, 47999]
# size list: 48000, time execution: 0.00347
# Linier Search O(N) : [48999, 48999]
# size list: 49000, time execution: 0.00307
# Linier Search O(N) : [49999, 49999]
# size list: 50000, time execution: 0.00370
# Linier Search O(N) : [50999, 50999]
# size list: 51000, time execution: 0.00423
# Linier Search O(N) : [51999, 51999]
# size list: 52000, time execution: 0.00468
# Linier Search O(N) : [52999, 52999]
# size list: 53000, time execution: 0.00511
# Linier Search O(N) : [53999, 53999]
# size list: 54000, time execution: 0.00382
# Linier Search O(N) : [54999, 54999]
# size list: 55000, time execution: 0.00375
# Linier Search O(N) : [55999, 55999]
# size list: 56000, time execution: 0.00402
# Linier Search O(N) : [56999, 56999]
# size list: 57000, time execution: 0.00381
# Linier Search O(N) : [57999, 57999]
# size list: 58000, time execution: 0.00390
# Linier Search O(N) : [58999, 58999]
# size list: 59000, time execution: 0.00392
# Linier Search O(N) : [59999, 59999]
# size list: 60000, time execution: 0.00485
# Linier Search O(N) : [60999, 60999]
# size list: 61000, time execution: 0.00428
# Linier Search O(N) : [61999, 61999]
# size list: 62000, time execution: 0.00409
# Linier Search O(N) : [62999, 62999]
# size list: 63000, time execution: 0.00467
# Linier Search O(N) : [63999, 63999]
# size list: 64000, time execution: 0.00438
# Linier Search O(N) : [64999, 64999]
# size list: 65000, time execution: 0.00474
# Linier Search O(N) : [65999, 65999]
# size list: 66000, time execution: 0.00581
# Linier Search O(N) : [66999, 66999]
# size list: 67000, time execution: 0.00442
# Linier Search O(N) : [67999, 67999]
# size list: 68000, time execution: 0.00465
# Linier Search O(N) : [68999, 68999]
# size list: 69000, time execution: 0.00475
# Linier Search O(N) : [69999, 69999]
# size list: 70000, time execution: 0.00476
# Linier Search O(N) : [70999, 70999]
# size list: 71000, time execution: 0.00526
# Linier Search O(N) : [71999, 71999]
# size list: 72000, time execution: 0.00496
# Linier Search O(N) : [72999, 72999]
# size list: 73000, time execution: 0.00509
# Linier Search O(N) : [73999, 73999]
# size list: 74000, time execution: 0.00619
# Linier Search O(N) : [74999, 74999]
# size list: 75000, time execution: 0.00676
# Linier Search O(N) : [75999, 75999]
# size list: 76000, time execution: 0.00533
# Linier Search O(N) : [76999, 76999]
# size list: 77000, time execution: 0.00647
# Linier Search O(N) : [77999, 77999]
# size list: 78000, time execution: 0.00548
# Linier Search O(N) : [78999, 78999]
# size list: 79000, time execution: 0.00621
# Linier Search O(N) : [79999, 79999]
# size list: 80000, time execution: 0.00536
# Linier Search O(N) : [80999, 80999]
# size list: 81000, time execution: 0.00636
# Linier Search O(N) : [81999, 81999]
# size list: 82000, time execution: 0.00636
# Linier Search O(N) : [82999, 82999]
# size list: 83000, time execution: 0.00575
# Linier Search O(N) : [83999, 83999]
# size list: 84000, time execution: 0.00639
# Linier Search O(N) : [84999, 84999]
# size list: 85000, time execution: 0.00554
# Linier Search O(N) : [85999, 85999]
# size list: 86000, time execution: 0.00665
# Linier Search O(N) : [86999, 86999]
# size list: 87000, time execution: 0.00684
# Linier Search O(N) : [87999, 87999]
# size list: 88000, time execution: 0.00623
# Linier Search O(N) : [88999, 88999]
# size list: 89000, time execution: 0.00797
# Linier Search O(N) : [89999, 89999]
# size list: 90000, time execution: 0.00627
# Linier Search O(N) : [90999, 90999]
# size list: 91000, time execution: 0.00661
# Linier Search O(N) : [91999, 91999]
# size list: 92000, time execution: 0.00893
# Linier Search O(N) : [92999, 92999]
# size list: 93000, time execution: 0.00687
# Linier Search O(N) : [93999, 93999]
# size list: 94000, time execution: 0.00679
# Linier Search O(N) : [94999, 94999]
# size list: 95000, time execution: 0.00735
# Linier Search O(N) : [95999, 95999]
# size list: 96000, time execution: 0.00724
# Linier Search O(N) : [96999, 96999]
# size list: 97000, time execution: 0.00681
# Linier Search O(N) : [97999, 97999]
# size list: 98000, time execution: 0.00737
# Linier Search O(N) : [98999, 98999]
# size list: 99000, time execution: 0.00675
# Linier Search O(N) : [99999, 99999]
# size list: 100000, time execution: 0.00701

# %% [markdown]
# ### Visualization Sum of List

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(size1, time1, 'g-', alpha=1,label="Binary Search")
plt.grid(True)

plt.plot(size2, time2, 'r-', alpha=1,label="Linear Search")
# Label the axes and provide a title
plt.title("haha")
plt.legend()
plt.show()
